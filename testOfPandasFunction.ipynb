# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'A':[1,2,3,4,np.nan]})
print(df['A'] > 2)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# Name: A, dtype: bool

# %%
df.isnull().any()
# Out:
# A    True
# dtype: bool

# %%
df.isnull().all()
# Out:
# A    False
# dtype: bool

# %%
df.loc[df['A'] > 2, 'A'] = 10
df
# Out:
#       A
# 0   1.0
# 1   2.0
# 2  10.0
# 3  10.0
# 4   NaN

# %%
df2 = pd.DataFrame({'A':[1,2],'B':[3,4]})
print(df.values)
# Out:
# [[1 3]
#  [2 4]]

# %%
df2.apply(len)
# Out:
# A    2
# B    2
# dtype: int64

# %%
df2.reset_index(drop=True)
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
df2.reset_index(drop=False)
# Out:
#    index  A  B
# 0      0  1  3
# 1      1  2  4

# %%
print(df['A'].map({1:'x', 2:'y'}))
# Out:
# 0    x
# 1    y
# Name: A, dtype: object

# %%
df2.groupby('A').size()
# Out:
# A
# 1    1
# 2    1
# dtype: int64

# %%
print(df2.empty)
# Out:
# False

# %%
print(df.dropna())
# Out:
#    A  B
# 0  1  3
# 1  2  4

# %%
df3 = pd.DataFrame()
print(df3.dropna())
# Out:
# Empty DataFrame
# Columns: []
# Index: []
